# %% [markdown]
# <a href="https://colab.research.google.com/github/rasaltejas/AQI_Justice/blob/main/Movies_Recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv("tmdb_5000_movies.csv")
credits = pd.read_csv("tmdb_5000_credits.csv")
movies.head(1)

# %%
credits.head(1)

# %%
movies.info()

# %%
# preprocessing
movies = movies.merge(credits, on='title')
movies = movies[['title', 'cast', 'crew', 'id', 'overview', 'keywords', 'genres' ]]

# %%
movies.head(1)

# %%
movies.isnull().sum()

# %%
movies.dropna(inplace=True)
movies.duplicated().sum()

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'
